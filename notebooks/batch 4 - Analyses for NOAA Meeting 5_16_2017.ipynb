# %% [markdown]
# ## Batch 4 - Popgen analyses for NOAA meeting on 5/16/2017
#
# <br>
#
# This notebook contains DAPC / PCA plots. Colors used for populations match colors used in otolith microchemistry analyses.
#
#
# <br>
#
# After final filtering, I had the following sample sizes:
#
# **Pohang '15:** 30 ( + 1 replicate)
#
# **Geoje '15:** 33
#
# **Namhae '15:** 16
#
# **Yellow Sea Block '16:** 23 ( + 1 replicate)
#
# **Jukbyeon '07:** 22 ( + 3 replicates)
#
# **Jinhae Bay '07 - Early:** 20 (+ 1 replicate)
#
# **Jinhae Bay '07 - Late:** 29 (+ 5 replicates)
#
# **Boryeong '07:** 20
#
# **Geoje '14:** 20 (+ 10 replicates)
#
#
#
#
# <br>
# <br>
#
# **5/9/2017 - 5/11/2017**
# <br>
# <br>
# <br>
#
# ### DAPC plots
#
# I want to look at DAPC plots several different ways. For each I'll look at ALL samples and then just at southern samples:
#
# 1. All retained individuals (without sample replicates)
# 2. No Sea Block or Boryeong samples (ie. Yellow Sea)
# 3. Only southern samples (no Sea Block, Boryeong, Jukbyeon)
# 4. All individuals, with the following sites combined: Sea Block and Boryeong as Yellow Sea, Jinhae Bay Early and Late as Jinhae, Geoje 2014 and 2015 as Geoje.
# 5. Only southern sampling sites with temporal replicates at Jinhae Bay and Geoje combined.
#
# <br>
#
# The DAPC script used for all of these individual analyses can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC_script_Pcod_4-5.R), with the base DAPC script [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/PCod_Korea_DAPC.R).
#
#
# The in-R help for creating a DAPC plot isn't very good, but there is a great manual on [this website](https://www.rdocumentation.org/packages/adegenet/versions/2.0.1/topics/dapc%20graphics).
#
# <br>
#
# ** ALL RETAINED INDIVIDUALS, WITHOUT SAMPLE REPLICATES **

# %% [markdown]
# GENEPOP = `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps.gen`
#
# PC = 14
#
# Proportion of Variance conserved by the principal components: 0.1460506
#
# ...variance explained by first discriminant function: 0.6265693
#
# ...variance explained by second discriminant function: 0.3008403
#
# ![img_noreps](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC/batch4/dapc_noreps_colors2.png?raw=true)

# %% [markdown]
# <br>
#
# **No Yellow Sea Samples (both Sea Block and Boryeong)**

# %% [markdown]
# GENEPOP = `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps_noYSBOR.gen`
#
# PC = 28
#
# Proportion of Variance conserved by the principal components: 0.2705905
#
# ...variance explained by first discriminant function: 0.8468807
#
# ...variance explained by second discriminant function: 0.06732317
#
# ![dapc_all_noYSBOR](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC/batch4/dapc_noreps_noYSBOR_colors2.png?raw=true)

# %% [markdown]
# <br>
# <br>
# ** Only Southern Samples **

# %% [markdown]
# GENEPOP = `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps_south.gen`
#
# PC = 35
#
# Proportion of Variance conserved by the principal components: 0.3949879
#
# ...variance explained by first discriminant function: 0.4008412
#
# ...variance explained by second discriminant function: 0.2177612
#
# ![dapc_noreps_south](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC/batch4/dapc_noreps_south_colors2.png?raw=true)
#
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ** COMBINE TEMPORAL REPLICATES AND YELLOW SEA SAMPLING SITES **
#
# batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps_combo.gen
#
# PC = 6
#
# Proportion of Variance conserved by the principal components: 0.08746617
#
# ...variance explained by first discriminant function: 0.675528
#
# ...variance explained by second discriminant function: 0.3107449
#
#
# ![img_noreps_combo](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC/batch4/dapc_combo_colors2.png?raw=true)

# %% [markdown]
# <br>
# <br>
# ** COMBINE TEMPORAL REPLICATES IN SOUTHERN POPULATIONS **
#
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_south_combo.gen`
#
# PC = 37
#
# Proportion of Variance conserved by the principal components: 0.3903558
#
# ...variance explained by first discriminant function: 0.5303903
#
# ...variance explained by second discriminant function: 0.3449362
#
#
#
#
#
# ![img_dapc_south_combo](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/DAPC/batch4/dapc_noreps_south_combo.png?raw=true)

# %% [markdown]
# <br>
# <br>
# <br>
#
#
# ### DAPC Assignment Probabilities
#
# These are the assignment probabilities per population, according to the DAPC analyses run to produce the charts above.
#
# <br>
# ** All populations **
#
# $assign.per.pop
#     PO031715_24: 0.3666667
#
#     GEO012315_21: 0.7575758
#
#     NA021015_30 : 0.1875000
#
#     YS121316_30: 0.9565217
#
#     JUK07_37.1: 0.9545455
#
#     JB121807_46: 0.4500000
#
#     JB021108_48.1: 0.3448276
#
#     BOR07_22:  0.6000000
#
#     GEO020414_9_300: 0.2500000
#
# <br>
#
# ** Excluding Yellow Sea Block 161, Boryeong **
#
# PO031715_24: 0.6000000
#
#     GEO012315_21: 0.8181818
#
#     NA021015_30 : 0.5000000
#
#     JUK07_37.1: 0.9545455
#
#     JB121807_46: 0.6000000
#
#     JB021108_48.1: 0.6551724
#
#     GEO020414_9_300: 0.4500000
#
# <br>
#
#
# ** Southern Populations**
#
# PO031715_24: 0.7000000
#
#     GEO012315_21: 0.8787879
#
#     NA021015_30 : 0.6875000
#
#
#     JB121807_46: 0.6500000
#
#     JB021108_48.1: 0.7500000
#
#     GEO020414_9_300: 0.7500000
#
# <br>
#
#
# **Southern Populations, Temporal Replicates Combined **
#
#     POHANG: 0.5806452
#
#     GEOJE:  0.8095238
#
#     NAMHAE : 0.6250000
#
#
#     JB: 0.8363636

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# ### PCA Analysis
#
#
# The PCA analyses run were:
# 1. All retained individuals, without replicates
# 2. Only southern individuals
# 3. All individuals, with the following sites combined: Sea Block and Boryeong as Yellow Sea, Jinhae Bay Early and Late as Jinhae, Geoje 2014 and 2015 as Geoje.
#
# <br>
#
# The code for all of these PCA analyses can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/PCA/batch4/PCA_adegenet_EP_Pcod.R).
#
# <br>
# <br>
#
#
# **Run on All individuals, No Replicates**
#
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps.gen`
#
# PCA eigenvalues heatmap can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_noreps_eigen.png?raw=true)
#
# ![img_all_pca](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_noreps_colors2.png?raw=true)
#
#
# <br>
# **Run on SOUTHERN individuals**
#
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_south.gen`
#
# PCA eigenvalues heat map can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_noreps_south_eigen.png?raw=true)
#
# ![img_south](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_south_colors2.png?raw=true)
#
# <br>
# <br>
#
# ** Run on All Individuals, with the following sites grouped together: Sea Block / Boryeong as Yellow Sea, Geoje 14 and 15 as Geoje, Jinhae Bay Early and Late as Jinhae.
#
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps_combo.gen`
#
# PCA eigenvalues heatmap can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_noreps_combo_eigen.png?raw=true)
#
# ![img_all_pca_combo](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_noreps_combo.png?raw=true)
#
#
# <br>
# <br>
#
#
# **Run on SOUTHERN individuals, with temporal replicates collapsed into a single site**
#
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_south_combo.gen`
#
# PCA eigenvalues heat map can be found [here]()
#
# ![img_south]()

# %% [markdown]
# ** 5/11/2017**
# <br>
#
# ** REMOVAL OF OUTLIERS IN PCA OF SOUTHERN POPULATIONS **

# %% [markdown]
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_south_rmoutliers.gen`
#
# PCA eigenvalues heat map can be found [here](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_south_rmout_eigen.png?raw=true)
#
# ![img_south_rmoutliers](https://github.com/mfisher5/PCod-Korea-repo/blob/master/analyses/pca_south_rmoutliers_colors2.png?raw=true)
#
#
# <br>

# %% [markdown]
# <br>
#
# ### Basic Popgen with GENEPOP: Pairwise Fst
#
# used `option 3` --> `suboption` to find pairwise Fst values.
#
# then used `option 3` --> `suboption 2` to bootstrap genic differentiation for pairwise p values.
#
# <br>
# ** Results saved in .xlsx file called popgen_genepop in analyses folder**
#
#
# <br>
#
# ### Basic Popgen with hierfstat: Fis
#
# My Fis estimates will be confounded by the presence of repeated samples, so I used the genepop file:
# `batch_4.filteredMAF_filteredLoci_filteredIndivids_filteredHWE_noreps.gen`
#
# I first ran [this script]() from Natalie to get the output files:
#
# `KoreaPcod_filtered_Hs.txt`, `KoreaPcod_filtered_Ho.txt`, `KoreaPcod_filtered_Fis.txt`, `KoreaPcod_filtered_Genotype_counts.txt`

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.hist(fis_all, bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
plt.suptitle("Haplotype-level Fis across populations")
plt.xlabel("Fis")
plt.ylabel("Frequency")
plt.show()

# %%
for i in range(0,len(header_pops)):
    plt.hist(fis_sets[i], bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
    plt.suptitle("Haplotype-level Fis in population " + pops[i] + ", n = " + str(sample_size[i]))
    plt.xlabel("Fis")
    plt.ylabel("Frequency")
    plt.show()
