# %% [markdown]
# ## Stacks pipeline batch 6 - data exploration & visualization
# ### (0.3 Individual missing data cutoff)
#
# <br>
#
# This code was copied over from the Alaskan PCod batch 2 notebook. All analyses with dates AFTER 7/18/17 have been completed for Korean PCod batch 6.
#
# <br>
# This notebook includes:
# 1. heterozygosity v. read depth
# 2. Haplotype Fis distribution
# 4. read depth by tag number, distribution of read depth per tag
# 5. Histogram of SNP position in read
# 6. Fst v. SNP position (for haplotypes with only 1 SNP)
# 7. Het v. SNP position
# 8. Fis v. heterozygosity
#
# <br>
# <br>
# #### 6/14/2017
# <br>
# ### (1) heterozygosity v. read depth
#
# **This uses a script from Dan Drinan to compare average observed heterozygosity v. read depth by individual. I ran the script on all individuals that were *retained after the filtering steps***
#
# **Observed heterozygosity was calculated using `genepop`**
#
# **Read depth was calculated as the number of sequences in the original `fastq` file. **

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/notebooks'

# %%
cd ../scripts

# %%
# !head -n 30 hetVsReadDepth.py

# %%
# !mv hetVsReadDepth.py ../samplesT142/hetVsReadDepth.py

# %%
cd ../samplesT142/
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/samplesT142

# %%
# !python hetVsReadDepth_unzipped.py \
-l ../analyses/batch_6_FinalFilteredIndivids30.txt \
-f ../stacks_b6_wgenome/batch_6.filteredMAF_filteredLoci_30filteredIndivids_filteredHWE.gen \
-o ../analyses/batch6_HetvReadDepth_filtered \
-d 4
# Out:
# Processing PO010715_02
# Processing PO010715_02_rep
# Processing PO010715_04
# Processing PO010715_06.1
# Processing PO010715_08.1
# Processing PO010715_10.1
# Processing PO010715_11.1
# Processing PO010715_12
# Processing PO010715_17.1
# Processing PO010715_19.1
# Processing PO010715_26
# Processing PO010715_27.1
# Processing PO010715_28.1
# Processing PO010715_29.1
# Processing PO020515_01
# Processing PO020515_03.1
# Processing PO020515_05.1
# Processing PO020515_06
# Processing PO020515_08.1
# Processing PO020515_09.1
# Processing PO020515_10.1
# Processing PO020515_14.1
# Processing PO020515_15.1
# Processing PO020515_16.1
# Processing PO020515_17.1
# Processing PO031715_03
# Processing PO031715_04
# Processing PO031715_13.1
# Processing PO031715_20.1
# Processing PO031715_23
# Processing PO031715_24
# Processing GE011215_01.1
# Processing GE011215_07.1
# Processing GE011215_08.1
# Processing GE011215_09.1
# Processing GE011215_10.1
# Processing GE011215_14.1
# Processing GE011215_15.1
# Processing GE011215_16.1
# Processing GE011215_18
# Processing GE011215_19
# Processing GE011215_20.1
# Processing GE011215_21.1
# Processing GE011215_22
# Processing GE011215_24.1
# Processing GE011215_28
# Processing GE011215_29.1
# Processing GE011215_30.1
# Processing GE012315_01.1
# Processing GE012315_03.1
# Processing GE012315_04.1
# Processing GE012315_05.1
# Processing GE012315_06.1
# Processing GE012315_08.1
# Processing GE012315_09.1
# Processing GE012315_10.1
# Processing GE012315_11.1
# Processing GE012315_17.1
# Processing GE012315_20.1
# Processing GE012315_22.1
# Processing GEO012315_02
# Processing GEO012315_12
# Processing GEO012315_18
# Processing GEO012315_21
# Processing NA021015_02.1
# Processing NA021015_03.1
# Processing NA021015_06.1
# Processing NA021015_08.1
# Processing NA021015_09.1
# Processing NA021015_10.1
# Processing NA021015_13.1
# Processing NA021015_14.1
# Processing NA021015_16.1
# Processing NA021015_17.1
# Processing NA021015_21.1
# Processing NA021015_22.1
# Processing NA021015_23
# Processing NA021015_25
# Processing NA021015_26
# Processing NA021015_30
# Processing YS_121316_01
# Processing YS_121316_03
# Processing YS_121316_05
# Processing YS_121316_13
# Processing YS_121316_17
# Processing YS_121316_18
# Processing YS_121316_20.1
# Processing YS_121316_21
# Processing YS_121316_22
# Processing YS_121316_23
# Processing YS_121316_24
# Processing YS_121316_25
# Processing YS_121316_26
# Processing YS_121316_27
# Processing YS_121316_28
# Processing YS_121316_29
# Processing YS121315_08.1
# Processing YS121315_10.1
# Processing YS121315_12
# Processing YS121315_12_300
# Processing YS121315_14.1
# Processing YS121315_15
# Processing YS121315_16
# Processing YS121316_30
# Processing JUK07_01
# Processing JUK07_02.1
# Processing JUK07_02_rep.1
# Processing JUK07_03
# Processing JUK07_06.1
# Processing JUK07_09.1
# Processing JUK07_09_rep.1
# Processing JUK07_14
# Processing JUK07_15
# Processing JUK07_16.1
# Processing JUK07_16_rep.1
# Processing JUK07_17
# Processing JUK07_18
# Processing JUK07_19
# Processing JUK07_20
# Processing JUK07_22
# Processing JUK07_25
# Processing JUK07_26
# Processing JUK07_27
# Processing JUK07_28
# Processing JUK07_29.1
# Processing JUK07_30
# Processing JUK07_32
# Processing JUK07_36.1
# Processing JUK07_37.1
# Processing JB121807_01
# Processing JB121807_03.1
# Processing JB121807_05
# Processing JB121807_06.1
# Processing JB121807_08
# Processing JB121807_08_rep
# Processing JB121807_11.1
# Processing JB121807_12.1
# Processing JB121807_14.1
# Processing JB121807_19.1
# Processing JB121807_20.1
# Processing JB121807_21.1
# Processing JB121807_24.1
# Processing JB121807_25
# Processing JB121807_27
# Processing JB121807_28.1
# Processing JB121807_30
# Processing JB121807_31.1
# Processing JB121807_32.1
# Processing JB121807_33.1
# Processing JB121807_34.1
# Processing JB121807_37
# Processing JB121807_38.1
# Processing JB121807_41.1
# Processing JB121807_42
# Processing JB121807_44
# Processing JB121807_46
# Processing JB121807_48.1
# Processing JB021108_02.1
# Processing JB021108_04.1
# Processing JB021108_05
# Processing JB021108_05_rep
# Processing JB021108_06
# Processing JB021108_07.1
# Processing JB021108_08.1
# Processing JB021108_09.1
# Processing JB021108_12.1
# Processing JB021108_13.1
# Processing JB021108_16
# Processing JB021108_17.1
# Processing JB021108_19.1
# Processing JB021108_20
# Processing JB021108_22.1
# Processing JB021108_25.1
# Processing JB021108_26.1
# Processing JB021108_29
# Processing JB021108_30
# Processing JB021108_32
# Processing JB021108_34
# Processing JB021108_35
# Processing JB021108_35_rep
# Processing JB021108_36.1
# Processing JB021108_36_rep.1
# Processing JB021108_37.1
# Processing JB021108_37_rep.1
# Processing JB021108_38.1
# Processing JB021108_39
# Processing JB021108_41.1
# Processing JB021108_44.1
# Processing JB021108_45
# Processing JB021108_46.1
# Processing JB021108_46_rep.1
# Processing JB021108_47.1
# Processing JB021108_48.1
# Processing BOR07_01
# Processing BOR07_02.1
# Processing BOR07_03
# Processing BOR07_04
# Processing BOR07_05.1
# Processing BOR07_06.1
# Processing BOR07_07.1
# Processing BOR07_08.1
# Processing BOR07_09
# Processing BOR07_10.1
# Processing BOR07_11.1
# Processing BOR07_12.1
# Processing BOR07_13.1
# Processing BOR07_14
# Processing BOR07_15
# Processing BOR07_16
# Processing BOR07_17.1
# Processing BOR07_18
# Processing BOR07_19.1
# Processing BOR07_20.1
# Processing BOR07_21.1
# Processing BOR07_22
# Processing GEO020414_10
# Processing GEO020414_11
# Processing GEO020414_11_300
# Processing GEO020414_13_300
# Processing GEO020414_14
# Processing GEO020414_14_300
# Processing GEO020414_15
# Processing GEO020414_15_300
# Processing GEO020414_16
# Processing GEO020414_16_300
# Processing GEO020414_17
# Processing GEO020414_17_300
# Processing GEO020414_2
# Processing GEO020414_23
# Processing GEO020414_23_300
# Processing GEO020414_24
# Processing GEO020414_24_300
# Processing GEO020414_25
# Processing GEO020414_25_300
# Processing GEO020414_26
# Processing GEO020414_27
# Processing GEO020414_29
# Processing GEO020414_3
# Processing GEO020414_30
# Processing GEO020414_4
# Processing GEO020414_5
# Processing GEO020414_6
# Processing GEO020414_7
# Processing GEO020414_8
# Processing GEO020414_8_300
# Processing GEO020414_9
# Processing GEO020414_9_300

# %%
cd ../analyses
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses

# %%
myfile = open("batch6_30_HetvReadDepth_filtered", "r")

count = 0
read_depth = []
prop_het = []

for line in myfile: 
    if count > 1: 
        new_depth = line.strip().split()[1]
        new_het = line.strip().split()[2]
        read_depth.append(new_depth)
        prop_het.append(new_het)
        count += 1
    else: 
        count += 1

myfile.close()

print "Processed ", count, " samples."
# Out:
# Processed  248  samples.

# %%
length = len(read_depth)
for i in range(0,length):
    read_depth[i] = float(read_depth[i])

length = len(prop_het)
for i in range(0,length):
    prop_het[i] = float(prop_het[i])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(read_depth, prop_het)
plt.suptitle("Heterozygosity by Read Depth")
plt.xlabel("Read depth")
plt.ylabel("Heterozygosity")
plt.show()

# %%
plt.close()

# %% [markdown]
# To find the correlation between the two:

# %%
np.corrcoef(read_depth, prop_het)
# Out:
# array([[ 1.        ,  0.23142827],
#        [ 0.23142827,  1.        ]])

# %% [markdown]
# **The correlation between heterozygosity and read depth is 0.7594**
#
#
# <br>
# <br>

# %% [markdown]
# **Colored by Population**

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses'

# %%
cd ../analyses
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses

# %%
myfile = open("batch6_30_HetvReadDepth_filtered", "r")

count = 0
read_depth = []
prop_het = []
colors = []

for line in myfile: 
    if count > 1: 
        new_depth = line.strip().split()[1]
        new_het = line.strip().split()[2]
        read_depth.append(new_depth)
        prop_het.append(new_het)
        count += 1
        sampleID = line.strip().split()[0]
        if sampleID.startswith("PO"):
            colors.append("firebrick")
        elif sampleID.startswith("GE011215") or sampleID.startswith("GE012315"):
            colors.append("sienna")
        elif sampleID.startswith("GEO020414"):
            colors.append("black")
        elif sampleID.startswith("NA"):
            colors.append("chartreuse")
        elif sampleID.startswith("YS"):
            colors.append("darkcyan")
        elif sampleID.startswith("JUK"):
            colors.append("navy")
        elif sampleID.startswith("JB121807"):
            colors.append("darkorchid")
        elif sampleID.startswith("JB021108"):
            colors.append("palevioletred")
        elif sampleID.startswith("BOR"):
            colors.append("gold")
    else: 
        count += 1

myfile.close()

print "Processed ", count, " samples."
# Out:
# Processed  248  samples.

# %%
length = len(read_depth)
for i in range(0,length):
    read_depth[i] = float(read_depth[i])

length = len(prop_het)
for i in range(0,length):
    prop_het[i] = float(prop_het[i])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.scatter(read_depth, prop_het, color = colors)
plt.suptitle("Heterozygosity by Read Depth")
plt.xlabel("Read depth")
plt.ylabel("Heterozygosity")
plt.show()

# %% [markdown]
# <br>
#
# **The correlation between heterozygosity and read depth is 0.7594**

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ### (2) Haplotype Fis distribution (R - hierfstat)
#
# **This looks at the frequency of Fis values across haplotypes - first overall, and then in each population. The haplotype is the combination of biallelic SNPs that is genotyped by stacks**
#
# **This Fis was calculated using hierfstat and adegenet in R. **
#
#
# <br>
# <br>
#
#
#
#
# **(1)** I ran this [r script](https://github.com/mfisher5/PCod-US-repo/blob/master/analyses/Fis.R) - borrowed from Natalie - to find per population Fis and heterozygosity.

# %% [markdown]
# <br>
# **(2)** Plot in frequency histogram based off of Natalie's [scallop notebook](https://github.com/nclowell/RAD_Scallops/blob/master/CRAGIG_run1/Notebooks/script_demos_notebooks/Plot%20num%20alleles%20per%20locus%20from%20catalog%20file.ipynb).

# %%
genepop = open("b6_30_Fis_hierfstat.txt", "r")
fis_all = []

counter = 1
NA_count = 0
total_count = 0
for line in genepop: 
    if counter == 1: 
            counter += 1
    else: 
        fis_values = line.strip().split()[1:]
        for i in fis_values:
            if i == "NA":
                NA_count += 1
                total_count += 1
            else: 
                fis_all.append(float(i))
                total_count += 1
        counter += 1

total_loci = counter - 2
print "Fis values recorded from ", total_loci, " loci."
print "Removed ", NA_count, " NAs from ", total_count, " Fis values"
# Out:
# Fis values recorded from  6624  loci.
# Removed  12575  NAs from  59616  Fis values

# %%
for i in range(0, len(fis_all)): 
    fis_all[i] = float(fis_all[i])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(fis_all, bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
plt.suptitle("Fis (per locus) across populations")
plt.xlabel("Fis")
plt.ylabel("Frequency")
plt.show()

# %%
fis_file = open("b6_30_Fis_hierfstat.txt", "r")
lines = fis_file.readlines() # exclude header
headerline = lines[0] # get header line
restlines = lines[1:] # get rest of lines
header_pops = headerline.strip().split("\t")
header_pops = header_pops[0:]
pops = ["Pohang '15", "Geoje '15", "Namhae '15", "YellowSea '16", "Jukbyeon '07", "Jin. Bay '07 Early", "Jin. Bay '07 Late", "Boryeong '07", "Geoje '14"]

# %%
header_pops
# Out:
# ['"PO031715_24"',
#  '"GEO012315_21"',
#  '"NA021015_30"',
#  '"YS121316_30"',
#  '"JUK07_37.1"',
#  '"JB021108_07.1"',
#  '"JB021108_48.1"',
#  '"BOR07_22"',
#  '"GEO020414_9_300"']

# %%
fis_sets = []
NA_count = 0
total_count = 0

snp_all_fis = []
for pop in header_pops:
    pop_fis = []
    pop_index = header_pops.index(pop) + 1
    for line in restlines:
        linelist = line.strip().split("\t")
        snp_fis = linelist[pop_index]
        if snp_fis == "NA":
            NA_count += 1
            total_count += 1
        elif snp_fis != "NA":
            snp_fis = float(snp_fis)
            pop_fis.append(snp_fis)
            snp_all_fis.append(snp_fis)
            total_count += 1
    fis_sets.append(pop_fis)

print "NA count: " + str(NA_count)
print "NAs made up " + str(float(NA_count)/float(total_count)*100)[0:5] + "% of your Fis estimates."
# Out:
# NA count: 12575
# NAs made up 21.09% of your Fis estimates.

# %%
for i in range(0,len(header_pops)):
    plt.hist(fis_sets[i], bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
    plt.suptitle("Haplotype-level Fis in population " + pops[i])
    plt.xlabel("Fis")
    plt.ylabel("Frequency")
    plt.show()

# %%
fis_file.close()

# %% [markdown]
# <br>
# <br>
# ### (2b) Locus Fis Distributions (Genepop)
#
# **(1) Generate the .INF genepop file (Option 5, suboption 1) and use Dan Drinan's script to parse it.**
# <br>
# **(2) Plot per locus Fis**

# %%
cd ../analyses
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses

# %%
# !head -n 20 parseGenepopINFandFST.py
# Out:
# ################################################################################
# #
# # parseGenepopINF.py - this is a script used to parse output files created
# # by genepop
# #
# # 2017-March-21
# # Daniel Drinan (ddrinan@uw.edu)
# #
# # population - HWE, He (INF), Ho (INF), Fis_wc (INF), Fis_RH (INF)
# ################################################################################
#
# import argparse
#
# parser = argparse.ArgumentParser()
# parser.add_argument("-i", "--INF", help=".INF file output from genepop (mutually exclusive to '-f')")
# parser.add_argument("-f", "--FST", help=".FST file output from genepop (mutually exclusive to '-i')")
# parser.add_argument("-s", "--SNP", help="SNP position is in the locus name", action='store_true')
# parser.add_argument("-o", "--OUTPUT", help="name of output file")
# args = parser.parse_args()

# %%
# !python parseGenepopINFandFST.py \
-i batch_6_filteredMAF_filteredLoci_30filteredIndivids_filteredHWE_noreps.txt.INF \
-o batch_6_30_INFgenepop_parsed_output.txt

# %%
## Get population codes ##
fisfile = open("batch_6_30_INFgenepop_parsed_output.txt", "r")

fisfile.readline()

pop_codes = []

for line in fisfile:
    if line.strip().split()[0] not in pop_codes:
        pop_codes.append(line.strip().split()[0])
fisfile.close()

# %%
print pop_codes
# Out:
# ['PO031715_24', 'GEO012315_21', 'NA021015_30', 'YS121316_30', 'JUK07_37.1', 'JB021108_07.1', 'JB021108_48.1', 'BOR07_22', 'GEO020414_9_300']

# %%
# create list of lists containing fis values #

fisfile = open("batch_6_30_INFgenepop_parsed_output.txt", "r")

lines = fisfile.readlines() # save all lines in file to variable
fisfile.close()
headerline = lines[0] # get header line
restlines = lines[1:] # get rest of lines

fis_sets = []
total_count = 0
pop_index = 0

snp_all_fis_gen = []
for pop in pop_codes:
    pop_fis = [] #create empty list
    for line in restlines:
        linelist = line.strip().split()
        if linelist[0] == pop: #if the population for that line matches pop we are interested in
            snp_fis = float(linelist[4])
            pop_fis.append(snp_fis) #append the snp fis to the pop specific fis list
            snp_all_fis_gen.append(snp_fis) #append the snp fis to the overall fis list
            total_count += 1
    pop_index += 1
    fis_sets.append(pop_fis)

print "Total SNPs counted: " + str(total_count)
# Out:
# Total SNPs counted: 47284

# %%
print len(snp_all_fis_gen)
# Out:
# 47284

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(snp_all_fis_gen, bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
plt.suptitle("Haplotype-level Fis across populations")
plt.xlabel("Fis")
plt.ylabel("Frequency")
plt.show()

# %%
plt.close()

# %%
for i in range(0,len(pop_codes)):
    plt.hist(fis_sets[i], bins = np.arange(-1, 1.1, .1)+0.05, color = "darkcyan")
    plt.suptitle("Haplotype-level Fis in population " + pop_codes[i])
    plt.xlabel("Fis")
    plt.ylabel("Frequency")
    plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# <br>
# <br>
# ### (3) Distribution of average read depth per tag ID
#
# **I found the read depth of each catalog tag (aka each locus from the reference "genome") in each individual, and then took an average of those read depths for each catalog tag. I then plotted this against tag ID, and as a frequency histogram.**
#
# **Read depth was calculated as the sum of the number of reads listed for that tag in the `.matches` files after `sstacks`**
#
# <br>
#
#
# Part of the following code was borrowed from Natalies [notebook](https://github.com/nclowell/RAD_Scallops/blob/master/CRAGIG_run1/Notebooks/data_processing_notebooks/plot_tagID_v_read_depth.ipynb).

# %%
cd ../stacks_b6_wgenome
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/stacks_b6_wgenome

# %%
myfile = open("../analyses/batch_6_FinalFilteredIndivids30.txt", "r")

filename_list = []
for line in myfile:
    filename = line.strip().split()[0]
    filename_list.append(filename + ".matches.tsv")
myfile.close()

# %%
print filename_list[0:5]
# Out:
# ['PO010715_02.matches.tsv', 'PO010715_02_rep.matches.tsv', 'PO010715_04.matches.tsv', 'PO010715_06.1.matches.tsv', 'PO010715_08.1.matches.tsv']

# %%
#initiate dictionary
rd_final_dict = {}
reps = 0

for file in filename_list:
    rd_dict = {}
    indfile = open(file,"r")
    lines = indfile.readlines()[1:]   #read all of file except header
    newcount = 0
    #create the individual's dictionary of read depths per locus
    for line in lines:
        linelist = line.strip().split()
        locus = int(linelist[2])
        count = int(linelist[6])
        if locus not in rd_dict:
            rd_dict[locus] = int(count) 
        elif locus in rd_dict:
            oldcount = rd_dict[locus]
            newcount = oldcount + count
            rd_dict[locus] = newcount
        else:
            print "Something funky is going on."
    #append all individual's counts to the final dictionary by locus
    locus_list = rd_dict.keys()
    for locus in locus_list: 
        reads = rd_dict[locus]
        if locus not in rd_final_dict: 
            rd_final_dict[locus] = [reads]
        else: 
            averages = rd_final_dict[locus]
            averages.append(reads)
            rd_final_dict[locus] = averages
    reps += 1
    print "file ", file, " counted."
    indfile.close()
# Out:
# file  PO010715_02.matches.tsv  counted.
# file  PO010715_02_rep.matches.tsv  counted.
# file  PO010715_04.matches.tsv  counted.
# file  PO010715_06.1.matches.tsv  counted.
# file  PO010715_08.1.matches.tsv  counted.
# file  PO010715_10.1.matches.tsv  counted.
# file  PO010715_11.1.matches.tsv  counted.
# file  PO010715_12.matches.tsv  counted.
# file  PO010715_17.1.matches.tsv  counted.
# file  PO010715_19.1.matches.tsv  counted.
# file  PO010715_26.matches.tsv  counted.
# file  PO010715_27.1.matches.tsv  counted.
# file  PO010715_28.1.matches.tsv  counted.
# file  PO010715_29.1.matches.tsv  counted.
# file  PO020515_01.matches.tsv  counted.
# file  PO020515_03.1.matches.tsv  counted.
# file  PO020515_05.1.matches.tsv  counted.
# file  PO020515_06.matches.tsv  counted.
# file  PO020515_08.1.matches.tsv  counted.
# file  PO020515_09.1.matches.tsv  counted.
# file  PO020515_10.1.matches.tsv  counted.
# file  PO020515_14.1.matches.tsv  counted.
# file  PO020515_15.1.matches.tsv  counted.
# file  PO020515_16.1.matches.tsv  counted.
# file  PO020515_17.1.matches.tsv  counted.
# file  PO031715_03.matches.tsv  counted.
# file  PO031715_04.matches.tsv  counted.
# file  PO031715_13.1.matches.tsv  counted.
# file  PO031715_20.1.matches.tsv  counted.
# file  PO031715_23.matches.tsv  counted.
# file  PO031715_24.matches.tsv  counted.
# file  GE011215_01.1.matches.tsv  counted.
# file  GE011215_07.1.matches.tsv  counted.
# file  GE011215_08.1.matches.tsv  counted.
# file  GE011215_09.1.matches.tsv  counted.
# file  GE011215_10.1.matches.tsv  counted.
# file  GE011215_14.1.matches.tsv  counted.
# file  GE011215_15.1.matches.tsv  counted.
# file  GE011215_16.1.matches.tsv  counted.
# file  GE011215_18.matches.tsv  counted.
# file  GE011215_19.matches.tsv  counted.
# file  GE011215_20.1.matches.tsv  counted.
# file  GE011215_21.1.matches.tsv  counted.
# file  GE011215_22.matches.tsv  counted.
# file  GE011215_24.1.matches.tsv  counted.
# file  GE011215_28.matches.tsv  counted.
# file  GE011215_29.1.matches.tsv  counted.
# file  GE011215_30.1.matches.tsv  counted.
# file  GE012315_01.1.matches.tsv  counted.
# file  GE012315_03.1.matches.tsv  counted.
# file  GE012315_04.1.matches.tsv  counted.
# file  GE012315_05.1.matches.tsv  counted.
# file  GE012315_06.1.matches.tsv  counted.
# file  GE012315_08.1.matches.tsv  counted.
# file  GE012315_09.1.matches.tsv  counted.
# file  GE012315_10.1.matches.tsv  counted.
# file  GE012315_11.1.matches.tsv  counted.
# file  GE012315_17.1.matches.tsv  counted.
# file  GE012315_20.1.matches.tsv  counted.
# file  GE012315_22.1.matches.tsv  counted.
# file  GEO012315_02.matches.tsv  counted.
# file  GEO012315_12.matches.tsv  counted.
# file  GEO012315_18.matches.tsv  counted.
# file  GEO012315_21.matches.tsv  counted.
# file  NA021015_02.1.matches.tsv  counted.
# file  NA021015_03.1.matches.tsv  counted.
# file  NA021015_06.1.matches.tsv  counted.
# file  NA021015_08.1.matches.tsv  counted.
# file  NA021015_09.1.matches.tsv  counted.
# file  NA021015_10.1.matches.tsv  counted.
# file  NA021015_13.1.matches.tsv  counted.
# file  NA021015_14.1.matches.tsv  counted.
# file  NA021015_16.1.matches.tsv  counted.
# file  NA021015_17.1.matches.tsv  counted.
# file  NA021015_21.1.matches.tsv  counted.
# file  NA021015_22.1.matches.tsv  counted.
# file  NA021015_23.matches.tsv  counted.
# file  NA021015_25.matches.tsv  counted.
# file  NA021015_26.matches.tsv  counted.
# file  NA021015_30.matches.tsv  counted.
# file  YS_121316_01.matches.tsv  counted.
# file  YS_121316_03.matches.tsv  counted.
# file  YS_121316_05.matches.tsv  counted.
# file  YS_121316_13.matches.tsv  counted.
# file  YS_121316_17.matches.tsv  counted.
# file  YS_121316_18.matches.tsv  counted.
# file  YS_121316_20.1.matches.tsv  counted.
# file  YS_121316_21.matches.tsv  counted.
# file  YS_121316_22.matches.tsv  counted.
# file  YS_121316_23.matches.tsv  counted.
# file  YS_121316_24.matches.tsv  counted.
# file  YS_121316_25.matches.tsv  counted.
# file  YS_121316_26.matches.tsv  counted.
# file  YS_121316_27.matches.tsv  counted.
# file  YS_121316_28.matches.tsv  counted.
# file  YS_121316_29.matches.tsv  counted.
# file  YS121315_08.1.matches.tsv  counted.
# file  YS121315_10.1.matches.tsv  counted.
# file  YS121315_12.matches.tsv  counted.
# file  YS121315_12_300.matches.tsv  counted.
# file  YS121315_14.1.matches.tsv  counted.
# file  YS121315_15.matches.tsv  counted.
# file  YS121315_16.matches.tsv  counted.
# file  YS121316_30.matches.tsv  counted.
# file  JUK07_01.matches.tsv  counted.
# file  JUK07_02.1.matches.tsv  counted.
# file  JUK07_02_rep.1.matches.tsv  counted.
# file  JUK07_03.matches.tsv  counted.
# file  JUK07_06.1.matches.tsv  counted.
# file  JUK07_09.1.matches.tsv  counted.
# file  JUK07_09_rep.1.matches.tsv  counted.
# file  JUK07_14.matches.tsv  counted.
# file  JUK07_15.matches.tsv  counted.
# file  JUK07_16.1.matches.tsv  counted.
# file  JUK07_16_rep.1.matches.tsv  counted.
# file  JUK07_17.matches.tsv  counted.
# file  JUK07_18.matches.tsv  counted.
# file  JUK07_19.matches.tsv  counted.
# file  JUK07_20.matches.tsv  counted.
# file  JUK07_22.matches.tsv  counted.
# file  JUK07_25.matches.tsv  counted.
# file  JUK07_26.matches.tsv  counted.
# file  JUK07_27.matches.tsv  counted.
# file  JUK07_28.matches.tsv  counted.
# file  JUK07_29.1.matches.tsv  counted.
# file  JUK07_30.matches.tsv  counted.
# file  JUK07_32.matches.tsv  counted.
# file  JUK07_36.1.matches.tsv  counted.
# file  JUK07_37.1.matches.tsv  counted.
# file  JB121807_01.matches.tsv  counted.
# file  JB121807_03.1.matches.tsv  counted.
# file  JB121807_05.matches.tsv  counted.
# file  JB121807_06.1.matches.tsv  counted.
# file  JB121807_08.matches.tsv  counted.
# file  JB121807_08_rep.matches.tsv  counted.
# file  JB121807_11.1.matches.tsv  counted.
# file  JB121807_12.1.matches.tsv  counted.
# file  JB121807_14.1.matches.tsv  counted.
# file  JB121807_19.1.matches.tsv  counted.
# file  JB121807_20.1.matches.tsv  counted.
# file  JB121807_21.1.matches.tsv  counted.
# file  JB121807_24.1.matches.tsv  counted.
# file  JB121807_25.matches.tsv  counted.
# file  JB121807_27.matches.tsv  counted.
# file  JB121807_28.1.matches.tsv  counted.
# file  JB121807_30.matches.tsv  counted.
# file  JB121807_31.1.matches.tsv  counted.
# file  JB121807_32.1.matches.tsv  counted.
# file  JB121807_33.1.matches.tsv  counted.
# file  JB121807_34.1.matches.tsv  counted.
# file  JB121807_37.matches.tsv  counted.
# file  JB121807_38.1.matches.tsv  counted.
# file  JB121807_41.1.matches.tsv  counted.
# file  JB121807_42.matches.tsv  counted.
# file  JB121807_44.matches.tsv  counted.
# file  JB121807_46.matches.tsv  counted.
# file  JB121807_48.1.matches.tsv  counted.
# file  JB021108_02.1.matches.tsv  counted.
# file  JB021108_04.1.matches.tsv  counted.
# file  JB021108_05.matches.tsv  counted.
# file  JB021108_05_rep.matches.tsv  counted.
# file  JB021108_06.matches.tsv  counted.
# file  JB021108_07.1.matches.tsv  counted.
# file  JB021108_08.1.matches.tsv  counted.
# file  JB021108_09.1.matches.tsv  counted.
# file  JB021108_12.1.matches.tsv  counted.
# file  JB021108_13.1.matches.tsv  counted.
# file  JB021108_16.matches.tsv  counted.
# file  JB021108_17.1.matches.tsv  counted.
# file  JB021108_19.1.matches.tsv  counted.
# file  JB021108_20.matches.tsv  counted.
# file  JB021108_22.1.matches.tsv  counted.
# file  JB021108_25.1.matches.tsv  counted.
# file  JB021108_26.1.matches.tsv  counted.
# file  JB021108_29.matches.tsv  counted.
# file  JB021108_30.matches.tsv  counted.
# file  JB021108_32.matches.tsv  counted.
# file  JB021108_34.matches.tsv  counted.
# file  JB021108_35.matches.tsv  counted.
# file  JB021108_35_rep.matches.tsv  counted.
# file  JB021108_36.1.matches.tsv  counted.
# file  JB021108_36_rep.1.matches.tsv  counted.
# file  JB021108_37.1.matches.tsv  counted.
# file  JB021108_37_rep.1.matches.tsv  counted.
# file  JB021108_38.1.matches.tsv  counted.
# file  JB021108_39.matches.tsv  counted.
# file  JB021108_41.1.matches.tsv  counted.
# file  JB021108_44.1.matches.tsv  counted.
# file  JB021108_45.matches.tsv  counted.
# file  JB021108_46.1.matches.tsv  counted.
# file  JB021108_46_rep.1.matches.tsv  counted.
# file  JB021108_47.1.matches.tsv  counted.
# file  JB021108_48.1.matches.tsv  counted.
# file  BOR07_01.matches.tsv  counted.
# file  BOR07_02.1.matches.tsv  counted.
# file  BOR07_03.matches.tsv  counted.
# file  BOR07_04.matches.tsv  counted.
# file  BOR07_05.1.matches.tsv  counted.
# file  BOR07_06.1.matches.tsv  counted.
# file  BOR07_07.1.matches.tsv  counted.
# file  BOR07_08.1.matches.tsv  counted.
# file  BOR07_09.matches.tsv  counted.
# file  BOR07_10.1.matches.tsv  counted.
# file  BOR07_11.1.matches.tsv  counted.
# file  BOR07_12.1.matches.tsv  counted.
# file  BOR07_13.1.matches.tsv  counted.
# file  BOR07_14.matches.tsv  counted.
# file  BOR07_15.matches.tsv  counted.
# file  BOR07_16.matches.tsv  counted.
# file  BOR07_17.1.matches.tsv  counted.
# file  BOR07_18.matches.tsv  counted.
# file  BOR07_19.1.matches.tsv  counted.
# file  BOR07_20.1.matches.tsv  counted.
# file  BOR07_21.1.matches.tsv  counted.
# file  BOR07_22.matches.tsv  counted.
# file  GEO020414_10.matches.tsv  counted.
# file  GEO020414_11.matches.tsv  counted.
# file  GEO020414_11_300.matches.tsv  counted.
# file  GEO020414_13_300.matches.tsv  counted.
# file  GEO020414_14.matches.tsv  counted.
# file  GEO020414_14_300.matches.tsv  counted.
# file  GEO020414_15.matches.tsv  counted.
# file  GEO020414_15_300.matches.tsv  counted.
# file  GEO020414_16.matches.tsv  counted.
# file  GEO020414_16_300.matches.tsv  counted.
# file  GEO020414_17.matches.tsv  counted.
# file  GEO020414_17_300.matches.tsv  counted.
# file  GEO020414_2.matches.tsv  counted.
# file  GEO020414_23.matches.tsv  counted.
# file  GEO020414_23_300.matches.tsv  counted.
# file  GEO020414_24.matches.tsv  counted.
# file  GEO020414_24_300.matches.tsv  counted.
# file  GEO020414_25.matches.tsv  counted.
# file  GEO020414_25_300.matches.tsv  counted.
# file  GEO020414_26.matches.tsv  counted.
# file  GEO020414_27.matches.tsv  counted.
# file  GEO020414_29.matches.tsv  counted.
# file  GEO020414_3.matches.tsv  counted.
# file  GEO020414_30.matches.tsv  counted.
# file  GEO020414_4.matches.tsv  counted.
# file  GEO020414_5.matches.tsv  counted.
# file  GEO020414_6.matches.tsv  counted.
# file  GEO020414_7.matches.tsv  counted.
# file  GEO020414_8.matches.tsv  counted.
# file  GEO020414_8_300.matches.tsv  counted.
# file  GEO020414_9.matches.tsv  counted.
# file  GEO020414_9_300.matches.tsv  counted.

# %%
#checking final dictionary counts to make sure they are appending
#and not summing
print rd_final_dict[100]
# Out:
# [140, 209, 135, 50, 77, 92, 55, 93, 28, 45, 53, 47, 90, 80, 59, 82, 62, 245, 67, 128, 141, 32, 144, 74, 66, 72, 79, 68, 39, 48, 83, 57, 66, 55, 89, 45, 169, 124, 100, 50, 155, 129, 83, 222, 78, 79, 57, 163, 59, 58, 10, 17, 41, 63, 23, 56, 57, 100, 59, 85, 87, 220, 19, 243, 117, 113, 57, 39, 92, 64, 118, 150, 87, 100, 95, 62, 114, 83, 69, 115, 36, 62, 60, 96, 200, 157, 83, 74, 99, 166, 91, 23, 121, 49, 39, 14, 18, 163, 145, 34, 76, 159, 94, 28, 280, 82, 46, 440, 94, 122, 24, 110, 204, 179, 46, 24, 117, 30, 67, 152, 54, 144, 102, 199, 105, 136, 56, 63, 78, 74, 61, 138, 13, 63, 50, 41, 105, 73, 62, 49, 42, 113, 67, 77, 151, 89, 108, 20, 118, 56, 27, 151, 27, 267, 364, 57, 49, 62, 50, 93, 78, 87, 68, 191, 55, 10, 95, 45, 101, 80, 70, 10, 30, 87, 123, 113, 113, 24, 22, 23, 125, 172, 147, 92, 85, 161, 38, 56, 21, 109, 136, 69, 177, 113, 133, 90, 144, 98, 137, 111, 65, 115, 27, 131, 78, 155, 29, 55, 39, 84, 99, 92, 74, 122, 52, 64, 97, 86, 84, 118, 126, 138, 154, 59, 49, 114, 60, 59, 73, 60, 41, 41, 133, 27, 49, 153, 99, 117, 94, 67]

# %%
#take averages at each locus
locus_list = rd_final_dict.keys()
rd_avg_dict = {}
for locus in locus_list: 
    newlist = rd_final_dict[locus]
    average = float(sum(newlist))/float(len(newlist))
    rd_avg_dict[locus] = average

# %%
#create a list of the read depth averages 
#by extracting values from dictionary
count_list = []
for locus in locus_list:
    avg_reads = rd_avg_dict[locus]
    count_list.append(avg_reads)

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(locus_list, count_list)
plt.suptitle("Read depth of tag v. Tag ID")
plt.xlabel("Tag ID")
plt.ylabel("Read depth of tag across individuals")
plt.show()

# %%
plt.close()

# %%
# subset data to focus on read depths less than 1000
count_less_1000 = [num for num in count_list if num < 1000]

# %%
# what number of tags have a read depth of less than 100,000
len(count_less_1000)
# Out:
# 25189

# %%
# what number of tags have a read depth of greater than 1000
len(count_list) - len(count_less_1000)
# Out:
# 8

# %%
plt.hist(count_less_1000, bins = np.arange(0,1000, 10),color = "darkcyan")
plt.xlabel("Read depth bin")
plt.ylabel("Frequency")
plt.suptitle("Distribution of Average Read Depth of\nindividual tags (subset, r depths < 1000)")
plt.show()

# %%
plt.close()

# %%
# subset read depths less than 400 (densest range in plot above)
count_less_400 = [num for num in count_list if num < 400]

# %%
plt.hist(count_less_1000, bins = np.arange(0,400, 10),color = "darkcyan")
plt.xlabel("Read depth bin")
plt.ylabel("Frequency")
plt.suptitle("Distribution of Average Read Depth of\nindividual tags (subset - r depths < 400)")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# ### Distribution of SNP Positions along Read Length
#
#
# **I plotted all of the SNP positions across the 142 bp read**
#
# **SNP position was found using the catalog of biallelic, polymorphic loci produced by Marine's filtering script.**

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/stacks_b6_wgenome'

# %%
# create a list of snp position using marine's catalog file
infile = open("batch_6.biallelic_catalog.tsv", "r")

snp_positions = []

for line in infile:
    linelist = line.strip().split("\t")
    if len(linelist) == 4:
        snp_pos = int(linelist[3])
        snp_positions.append(snp_pos)
    elif len(linelist) == 5:
        snp_pos = int(linelist[3])
        snp_positions.append(snp_pos)
        snp_pos = int(linelist[4])
        snp_positions.append(snp_pos)
        
infile.close()

# %%
len(snp_positions)
# Out:
# 10054

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
# plot histogram
plt.hist(snp_positions, bins = np.arange(0,100, 5), color = "darkcyan")
plt.xlabel("SNP position along read")
plt.ylabel("Number of SNPs")
plt.suptitle("Distribution of SNP positions")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
#
# <br>
# <br>
#
# ### Fst v. SNP position
#
# ** I plotted the Fst of each locus against the position of the SNP along the 1422 bp read**
#
# ** Fst of each locus was found by running `genepop` and then using Dan Drinan's parsing script.**
#
#
# <br>

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/stacks_b6_wgenome'

# %%
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses

# %% [markdown]
# I first have to parse genepop output with Dan's script.
#
# **(1)** Ran genepop option **6** >> **1**
#
# **(2)** Used Dan's python script to parse genepop output

# %%
# !head parseGenepopINFandFST.py
# Out:
# ################################################################################
# #
# # parseGenepopINF.py - this is a script used to parse output files created
# # by genepop
# #
# # 2017-March-21
# # Daniel Drinan (ddrinan@uw.edu)
# #
# # population - HWE, He (INF), Ho (INF), Fis_wc (INF), Fis_RH (INF)
# ################################################################################

# %%
# !python parseGenepopINFandFST.py \
-f batch_6_filteredMAF_filteredLoci_30filteredIndivids_filteredHWE_noreps.txt.FST \
-o batch_6_30_FSTgenepop_parsed_output.txt

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses'

# %%
# create a dictionary with snp positions at each locus
# uses marine's catalog file, only for haplotypes with a single snp

infile = open("../stacks_b6_wgenome/batch_6.biallelic_catalog.tsv", "r")

#create dictionary of snp positions by locus
snp_pos_dict = {}

for line in infile:
    linelist = line.strip().split("\t")
    if len(linelist) == 4:
        snp_pos = int(linelist[3])
        locus = linelist[0]
        snp_pos_dict[locus] = snp_pos
    
        
infile.close()


infile2 = open("batch_6_30_FSTgenepop_parsed_output.txt", "r")

# create dictionary of fst values by locus
fst_dict = {}

for line in infile2:
    if "locus" not in line:
        locus = line.strip().split()[0]
        fst = float(line.strip().split()[2])
        fst_dict[locus] = fst

infile2.close()

# %%
# check to make sure that all SNPs from the FST genepop file are in the 
#SNP list from the biallelic catalog.

loci_2snps = []
fst_loci_list = fst_dict.keys()
snp_loci_list = snp_pos_dict.keys()
for locus in fst_loci_list:
    if locus not in snp_loci_list:
        loci_2snps.append(locus)
print "These are the loci that have two SNPs, and so were taken out of this analysis:"
print loci_2snps
# Out:
# These are the loci that have two SNPs, and so were taken out of this analysis:
# ['19397', '22262', '19975', '16700', '2681', '99', '7185', '10888', '16063', '20730', '20735', '21938', '20085', '18931', '1765', '6776', '23075', '23074', '15852', '11138', '19512', '23247', '6436', '19930', '9380', '15131', '8055', '24743', '19747', '16451', '9926', '19262', '14823', '14858', '23963', '9734', '7103', '1685', '14772', '21316', '6454', '20142', '21766', '7124', '1402', '18101', '1548', '22931', '17710', '20354', '6446', '17475', '22323', '16463', '4809', '12978', '12979', '15381', '17904', '19400', '23849', '10147', '1997', '7329', '23280', '14086', '13277', '6513', '2212', '9289', '18393', '23806', '18982', '23129', '1221', '18887', '4570', '13403', '11936', '12671', '6885', '6071', '10247', '5109', '14455', '1266', '15515', '2969', '1078', '17858', '21782', '13585', '1798', '4593', '3899', '24051', '2900', '701', '14611', '19084', '12610', '4678', '11704', '10542', '11145', '13810', '19941', '10890', '4687', '17036', '21294', '6207', '15860', '16247', '13069', '17831', '7197', '16010', '12214', '9971', '4772', '14197', '8725', '3657', '22608', '21985', '16949', '8894', '3469', '664', '3077', '20327', '16773', '1694', '1690', '6847', '9332', '20642', '6709', '8328', '21825', '1677', '19043', '12290', '11987', '20366', '7864', '8976', '24202', '4265', '4666', '17704', '20777', '7096', '9316', '6857', '18243', '16678', '12706', '13182', '13267', '21127', '7335', '21444', '7832', '8998', '3060', '2082', '20450', '12306', '11908', '7789', '12687', '10827', '7817', '13220', '505', '15547', '15545', '7578', '9812', '8818', '17788', '12098', '10783', '18692', '5', '6658', '1844', '5136', '13202', '20007', '20553', '15782', '8426', '9892', '6043', '2620', '9581', '774', '71', '860', '23660', '15228', '16556', '21046', '10076', '24309', '4323', '15241', '21970', '9876', '7391', '12383', '22850', '2930', '733', '8566', '12302', '11171', '5490', '10312']

# %%
# create list of loci
# from the Fis file b/c of extra filtering done AFTER marine's file generated.

loci_list = fst_dict.keys()
snp_loci_list = snp_pos_dict.keys()
snp_pos_list = []
fst_list = []

for locus in loci_list:
    if locus in snp_loci_list:
        snp_pos = int(snp_pos_dict[locus])
        snp_pos_list.append(snp_pos)
        fst = float(fst_dict[locus])
        fst_list.append(fst)

# %%
#create scatterplot
plt.scatter(snp_pos_list, fst_list)
plt.suptitle("Fst by SNP position")
plt.xlabel("SNP position along read")
plt.ylabel("Fst of SNP")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
#
#
# <br>
# ### Heterozygosity v. SNP position
#
# ** This plots the observed heterozygosity of the haplotype against the SNP position in the 92 bp read**
#
# **SNP position was found using Marine's filtering script output for biallelic, polymorphic SNPs**
#
# **Heterozygosity was found using `genepop` and then parsing the output with Dan Drinan's script.**
#
# <br>
#
# <br>
#
# <br>
# I first need a parsed .INF genepop file...
#
# **(1)** Genepop option **5** >> **1**
#
# **(2)** Use Dan's script to parse out the .INF output file.

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses'

# %%
# !python parseGenepopINFandFST.py \
-i batch_6_filteredMAF_filteredLoci_30filteredIndivids_filteredHWE_noreps.txt.INF \
-o batch_6_30_INFgenepop_parsed_output.txt

# %%
infile = open("batch_6_30_INFgenepop_parsed_output.txt", "r")

# create a list of populations and a dictionary 
# dictionary keys are loci, values are list of He by population

h_dict = {}
pop_list = []

for line in infile: 
    if "pop" not in line:
        #create population list
        linelist = line.strip().split()
        population = linelist[0]
        if population not in pop_list:
            pop_list.append(population)
        # create new dictionary entry to append to existing entry
        locus = linelist[1]
        if locus not in h_dict.keys():
            Ho = float(linelist[3])
            h_dict[locus] = [Ho]
        elif locus in h_dict.keys():
            het_list = h_dict[locus]
            Ho = float(linelist[3])
            het_list.append(Ho)
            h_dict[locus] = het_list

infile.close()

# %%
loci_list = h_dict.keys()
loci_list[0:5]
# Out:
# ['4446', '11544', '19397', '5983', '19395']

# %% [markdown]
# Some of the loci don't have the heterozygosity measurements for all of the populations, while others do:

# %%
h_dict['4446']
# Out:
# [0.0333333333333,
#  0.0606060606061,
#  0.0,
#  0.0,
#  0.0454545454545,
#  0.0666666666667,
#  0.115384615385,
#  0.0,
#  0.0]

# %% [markdown]
# *this locus has calculated heterozygosities for all populations*

# %%
h_dict['5983']
# Out:
# [0.0454545454545]

# %% [markdown]
# *this locus has calculated heterozygosities for only 1 / 9 populations*

# %% [markdown]
# This was an error while parsing the genepop output because of the stupid way that genepop formats its output files. It's not expected to greatly impact the graphs that I made, so I won't worry about this too much, but will just have to keep it in mind going forward.

# %%
# create a dictionary with snp positions at each locus
# uses marine's catalog file, only for haplotypes with a single snp

infile = open("../stacks_b6_wgenome/batch_6.biallelic_catalog.tsv", "r")

#create dictionary of snp positions by locus
snp_pos_dict = {}

for line in infile:
    linelist = line.strip().split("\t")
    if len(linelist) == 4:
        snp_pos = int(linelist[3])
        locus = linelist[0]
        snp_pos_dict[locus] = snp_pos
    
        
infile.close()

snp_loci_list = snp_pos_dict.keys()

# %%
# get list of loci
loci_list = h_dict.keys()
avg_he_list = []
snp_pos_list = []

#find average he at each locus
for locus in loci_list:
    if locus in snp_loci_list:
        snp_pos = int(snp_pos_dict[locus])
        snp_pos_list.append(snp_pos)
        he_list = h_dict[locus]
        sum = 0
        for he in he_list:
            sum += float(he)
        average = float(sum)/float(len(he_list))
        avg_he_list.append(average)

# %%
len(avg_he_list)
# Out:
# 6402

# %%
len(snp_pos_list)
# Out:
# 6402

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(snp_pos_list, avg_he_list)
plt.suptitle("Heterozygosity by SNP position")
plt.xlabel("SNP position along read")
plt.ylabel("Ho of SNP")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# <br>
# <br>
#
# ### Fis v. Heterozygosity
#
# ** This plots locus-specific Fis values against observed heterozygosity**
#
#
# **Both Fis and Ho were calculated using `genepop`**
#
#
#
# <br>
#
# <br>
# From the last two visualizations, I already have He and Fis lists. The indices should be the same since they are both listed in order of SNP position.

# %%
len(avg_he_list)
# Out:
# 6402

# %%
# create a dictionary with snp positions at each locus
# uses marine's catalog file, only for haplotypes with a single snp

infile = open("../stacks_b6_wgenome/batch_6.biallelic_catalog.tsv", "r")

#create dictionary of snp positions by locus
snp_pos_dict = {}

for line in infile:
    linelist = line.strip().split("\t")
    if len(linelist) == 4:
        snp_pos = int(linelist[3])
        locus = linelist[0]
        snp_pos_dict[locus] = snp_pos
    
        
infile.close()


infile2 = open("batch_6_30_FSTgenepop_parsed_output.txt", "r")

# create dictionary of fis values by locus
fis_dict = {}

for line in infile2:
    if "locus" not in line:
        locus = line.strip().split()[0]
        fis = float(line.strip().split()[1])
        fis_dict[locus] = fis

infile2.close()

# %%
# check to make sure that all SNPs from the FST genepop file are in the 
#SNP list from the biallelic catalog.

loci_2snps = []
fis_loci_list = fis_dict.keys()
snp_loci_list = snp_pos_dict.keys()
for locus in fis_loci_list:
    if locus not in snp_loci_list:
        loci_2snps.append(locus)
print "These are the loci that have two SNPs, and so were taken out of this analysis:"
print loci_2snps
# Out:
# These are the loci that have two SNPs, and so were taken out of this analysis:
# ['19397', '22262', '19975', '16700', '2681', '99', '7185', '10888', '16063', '20730', '20735', '21938', '20085', '18931', '1765', '6776', '23075', '23074', '15852', '11138', '19512', '23247', '6436', '19930', '9380', '15131', '8055', '24743', '19747', '16451', '9926', '19262', '14823', '14858', '23963', '9734', '7103', '1685', '14772', '21316', '6454', '20142', '21766', '7124', '1402', '18101', '1548', '22931', '17710', '20354', '6446', '17475', '22323', '16463', '4809', '12978', '12979', '15381', '17904', '19400', '23849', '10147', '1997', '7329', '23280', '14086', '13277', '6513', '2212', '9289', '18393', '23806', '18982', '23129', '1221', '18887', '4570', '13403', '11936', '12671', '6885', '6071', '10247', '5109', '14455', '1266', '15515', '2969', '1078', '17858', '21782', '13585', '1798', '4593', '3899', '24051', '2900', '701', '14611', '19084', '12610', '4678', '11704', '10542', '11145', '13810', '19941', '10890', '4687', '17036', '21294', '6207', '15860', '16247', '13069', '17831', '7197', '16010', '12214', '9971', '4772', '14197', '8725', '3657', '22608', '21985', '16949', '8894', '3469', '664', '3077', '20327', '16773', '1694', '1690', '6847', '9332', '20642', '6709', '8328', '21825', '1677', '19043', '12290', '11987', '20366', '7864', '8976', '24202', '4265', '4666', '17704', '20777', '7096', '9316', '6857', '18243', '16678', '12706', '13182', '13267', '21127', '7335', '21444', '7832', '8998', '3060', '2082', '20450', '12306', '11908', '7789', '12687', '10827', '7817', '13220', '505', '15547', '15545', '7578', '9812', '8818', '17788', '12098', '10783', '18692', '5', '6658', '1844', '5136', '13202', '20007', '20553', '15782', '8426', '9892', '6043', '2620', '9581', '774', '71', '860', '23660', '15228', '16556', '21046', '10076', '24309', '4323', '15241', '21970', '9876', '7391', '12383', '22850', '2930', '733', '8566', '12302', '11171', '5490', '10312']

# %%
# create list of loci
# from the Fis file b/c of extra filtering done AFTER marine's file generated.

loci_list = fis_dict.keys()
snp_loci_list = snp_pos_dict.keys()
snp_pos_list = []
fis_list = []

for locus in loci_list:
    if locus in snp_loci_list:
        snp_pos = int(snp_pos_dict[locus])
        snp_pos_list.append(snp_pos)
        fis = float(fis_dict[locus])
        fis_list.append(fis)

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(avg_he_list, fis_list)
plt.suptitle("Fis by Heterozygosity")
plt.xlabel("Ho of SNP")
plt.ylabel("Fis of SNP")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# <br>
#
# ### Number of loci genotyped v. Heterozygosity per individual
#
# **This looks at the number of loci actually genotyped in each individual v. their heterozygosity**

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/analyses'

# %%
### Find the percent missing data per individual and the % of heterozygotes per individual from a genepop file ###
infile = open("../stacks_b6_wgenome/batch_6.filteredMAF_filteredLoci_30filteredIndivids_filteredHWE.gen", "r")

for line in infile:
    if line.startswith("Pop"):
        break

import collections 
sample_count = 0
pop_count = 1

missing_data = collections.OrderedDict()
obs_het = collections.OrderedDict()

for line in infile:
    if line.startswith("Pop"):
        pop_count += 1
    else:
        sampID = line.strip().split()[0]
        missing = line.count("0000")
        hets = line.count("0102")
        genotyped = float(6624)-float(missing)
        missing_data[sampID] = genotyped
        p_het = float(hets)/float(genotyped)
        obs_het[sampID] = p_het
        sample_count += 1
infile.close()

print sample_count
# Out:
# 247

# %%
#check that it read all pops
print pop_count
# Out:
# 9

# %%
#check that it read all samples
print len(missing_data.keys())
# Out:
# 247

# %%
#make sure that the ordered dictionary is working
test_fromdict = missing_data.values()
print "test", test_fromdict[0]
print "actual", missing_data["PO010715_02,"]
# Out:
# test 6583.0
# actual 6583.0

# %%
#make sure that the ordered dictionary is working
test_fromdict = obs_het.values()
print "test", test_fromdict[0]
print "actual", obs_het["PO010715_02,"]
# Out:
# test 0.230442047699
# actual 0.230442047699

# %%
#make sure that the ordered dictionary is working
test_fromdict = obs_het.values()
print "test", test_fromdict[1]
print "actual", obs_het["PO010715_02_rep,"]
# Out:
# test 0.243087207536
# actual 0.243087207536

# %%
#make sure that the ordered dictionary is working
test_fromdict = missing_data.values()
print "test", test_fromdict[1]
print "actual", missing_data["PO010715_02_rep,"]
# Out:
# test 6582.0
# actual 6582.0

# %%
#make corresponding list of observed heterozygosities and missing data
ho_list = obs_het.values()
missing_list = missing_data.values()

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(missing_list, ho_list)
plt.suptitle("Missing Data by Heterozygosity")
plt.ylabel("Ho of Individual")
plt.xlabel("# Loci Genotyped")
plt.show()

# %%
plt.close()

# %%
## Find the heterozygosity per individual using output from Dan's HetVreaddepth script

infile = open("batch6_30_HetvReadDepth_filtered")

het_dict = {}
infile.readline()
for line in infile:
    sample = line.strip().split()[0]+','
    prop_het = line.strip().split()[2]
    het_dict[sample] = prop_het
infile.close

samples = het_dict.keys()
genotyped_list = []
het_list = []

for i in samples:
    genotyped_list.append(missing_data[i])
    het_list.append(het_dict[i])

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(genotyped_list, het_list)
plt.suptitle("# Loci Genotyped by Heterozygosity")
plt.ylabel("Ho of Individual")
plt.xlabel("# Loci Genotyped")
plt.show()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
#
#
# #### 6/2017
# <br>
#
#
#
# <br>
# <br>
# ### Population expected Heterozygosity v. Population average read depth

# %%
### find pop He by averaging He in .INF parsed file across loci


infile = open("batch_6_30_INFgenepop_parsed_output.txt", "r")

poh15 = []
ge15 = []
na15 = []
ys16 = []
juk07 = []
jb07e = []
jb07l = []
bor07 = []
ge14 = []


for line in infile:
    if line.startswith("PO"):
        poh15.append(float(line.strip().split()[2]))
    elif line.startswith("GE011215") or line.startswith("GE012315"):
        ge15.append(float(line.strip().split()[2]))
    elif line.startswith("NA"):
        na15.append(float(line.strip().split()[2]))
    elif line.startswith("YS"):
        ys16.append(float(line.strip().split()[2]))
    elif line.startswith("JUK"):
        juk07.append(float(line.strip().split()[2]))
    elif line.startswith("JB121807"):
        jb07e.append(float(line.strip().split()[2]))
    elif line.startswith("JB021108"):
        jb07l.append(float(line.strip().split()[2]))
    elif line.startswith("BOR"):
        bor07.append(float(line.strip().split()[2]))
    elif line.startswith("GEO020414"):
        ge14.append(float(line.strip().split()[2]))
infile.close()

# %%
exp_het = [float(sum(poh15))/float(len(poh15)), float(sum(ge15))/float(len(ge15)), float(sum(na15))/float(len(na15)), float(sum(ys16))/float(len(ys16)), float(sum(juk07))/float(len(juk07)), float(sum(jb07e))/float(len(jb07e)), float(sum(jb07l))/float(len(jb07l)), float(sum(bor07))/float(len(bor07)), float(sum(ge14))/float(len(ge14))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-182-ae0a5f695b6f> in <module>()
# ----> 1 exp_het = [float(sum(poh15))/float(len(poh15)), float(sum(ge15))/float(len(ge15)), float(sum(na15))/float(len(na15)), float(sum(ys16))/float(len(ys16)), float(sum(juk07))/float(len(juk07)), float(sum(jb07e))/float(len(jb07e)), float(sum(jb07l))/float(len(jb07l)), float(sum(bor07))/float(len(bor07)), float(sum(ge14))/float(len(ge14))]
#
# TypeError: 'float' object is not callable

# %%
#find population average read depth 


infile = open("batch6_30_HetvReadDepth_filtered", "r")

poh15 = []
ge15 = []
na15 = []
ys16 = []
juk07 = []
jb07e = []
jb07l = []
bor07 = []
ge14 = []


for line in infile:
    if line.startswith("PO"):
        poh15.append(float(line.strip().split()[2]))
    elif line.startswith("GE011215") or line.startswith("GE012315"):
        ge15.append(float(line.strip().split()[2]))
    elif line.startswith("NA"):
        na15.append(float(line.strip().split()[2]))
    elif line.startswith("YS"):
        ys16.append(float(line.strip().split()[2]))
    elif line.startswith("JUK"):
        juk07.append(float(line.strip().split()[2]))
    elif line.startswith("JB121807"):
        jb07e.append(float(line.strip().split()[2]))
    elif line.startswith("JB021108"):
        jb07l.append(float(line.strip().split()[2]))
    elif line.startswith("BOR"):
        bor07.append(float(line.strip().split()[2]))
    elif line.startswith("GEO020414"):
        ge14.append(float(line.strip().split()[2]))
infile.close()

# %%
read_depths = [float(sum(poh15))/float(len(poh15)), float(sum(ge15))/float(len(ge15)), float(sum(na15))/float(len(na15)), float(sum(ys16))/float(len(ys16)), float(sum(juk07))/float(len(juk07)), float(sum(jb07e))/float(len(jb07e)), float(sum(jb07l))/float(len(jb07l)), float(sum(bor07))/float(len(bor07)), float(sum(ge14))/float(len(ge14))]

# %%
print exp_het
print read_depths
# Out:
# [0.16324334779825098, 0.15860103920472, 0.14276256450770328, 0.15089472215707597, 0.1473468417656152, 0.13795096526417816, 0.16696520534595063, 0.147071367684073]
# [2692075.8372093025, 2062103.2571428572, 2434519.3333333335, 2651982.9523809524, 2637274.1333333333, 2062387.857142857, 3766851.1666666665, 2435556.4318181816]

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(read_depths, exp_het)
plt.suptitle("Expected Heterozygosity by Avg Read depth, per population")
plt.ylabel("He of Population")
plt.xlabel("Avg. Read Depth")
plt.show()

# %%
plt.close()

# %%
np.corrcoef(read_depths, exp_het)
# Out:
# array([[ 1.       ,  0.6455738],
#        [ 0.6455738,  1.       ]])

# %% [markdown]
# <br>
# <br>
# ### Fis v. read depth, by population

# %%
### find pop Fis by averaging Fis in .INF parsed file across loci


infile = open("genepop/batch_2_INFgenepop_parsed_output.txt", "r")

kod = []
ad = []
wc = []
hs = []
ps = []
gs = []
pws = []
up = []


for line in infile:
    if line.startswith("KOD"):
        kod.append(float(line.strip().split()[4]))
    elif line.startswith("AD"):
        ad.append(float(line.strip().split()[4]))
    elif line.startswith("WC"):
        wc.append(float(line.strip().split()[4]))
    elif line.startswith("HS"):
        hs.append(float(line.strip().split()[4]))
    elif line.startswith("PS"):
        ps.append(float(line.strip().split()[4]))
    elif line.startswith("GS"):
        gs.append(float(line.strip().split()[4]))
    elif line.startswith("PWS"):
        pws.append(float(line.strip().split()[4]))
    elif line.startswith("UP"):
        up.append(float(line.strip().split()[4]))
infile.close()

fis = [float(sum(kod))/float(len(kod)), float(sum(ad))/float(len(ad)), float(sum(wc))/float(len(wc)), float(sum(hs))/float(len(hs)), float(sum(ps))/float(len(ps)), float(sum(gs))/float(len(gs)), float(sum(pws))/float(len(pws)), float(sum(up))/float(len(up))]

# %%
#find population average read depth 


infile = open("batch2_HetvReadDepth_filtered", "r")

kod = []
ad = []
wc = []
hs = []
ps = []
gs = []
pws = []
up = []


for line in infile:
    if line.startswith("KOD"):
        kod.append(float(line.strip().split()[1]))
    elif line.startswith("AD"):
        ad.append(float(line.strip().split()[1]))
    elif line.startswith("WC"):
        wc.append(float(line.strip().split()[1]))
    elif line.startswith("HS"):
        hs.append(float(line.strip().split()[1]))
    elif line.startswith("PS"):
        ps.append(float(line.strip().split()[1]))
    elif line.startswith("GS"):
        gs.append(float(line.strip().split()[1]))
    elif line.startswith("PWS"):
        pws.append(float(line.strip().split()[1]))
    elif line.startswith("UP"):
        up.append(float(line.strip().split()[1]))
infile.close()


read_depths = [float(sum(kod))/float(len(kod)), float(sum(ad))/float(len(ad)), float(sum(wc))/float(len(wc)), float(sum(hs))/float(len(hs)), float(sum(ps))/float(len(ps)), float(sum(gs))/float(len(gs)), float(sum(pws))/float(len(pws)), float(sum(up))/float(len(up))]

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot

plt.scatter(read_depths, fis)

plt.suptitle("Fis values by Avg Read depth, per population")
plt.ylabel("Fis of Population")
plt.xlabel("Avg. Read Depth")

plt.show()

# %%
plt.close()

# %%
np.corrcoef(read_depths, fis)
# Out:
# array([[ 1.       , -0.5080224],
#        [-0.5080224,  1.       ]])

# %% [markdown]
# <br>
# <br>
#
# ### Fis per locus v. average read depth per locus

# %% [markdown]
# use .INF file for Fis per locus per population

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/analyses'

# %%
# !head -n 20 readDepthVsFis_revised.py
# Out:
# # script for Mary that will estimate average read depth per population per locus
# # and compare it to Fis values (from a file Mary already has).
# #
# #
# # population names in '-s' file and '-f' files must match
# #
#
# import argparse, sys
#
# parser = argparse.ArgumentParser()
# parser.add_argument("-s", "--samples", help="file containing samples to parse. each line contains 'sample pop'.")
# parser.add_argument("-d", "--directory", help="directory containing 'matches' files.")
# parser.add_argument("-o", "--output", help="output file.")
# parser.add_argument("-f", "--fis_file", help="file containing Fis information.")
#
# args = parser.parse_args()
#
# sample_list_file = open(args.samples, 'r') # some file that has a list of the 'sample population'
# matches_path = args.directory # directory of matches files

# %%
# !python readDepthVsFis_revised.py \
-s batch_6_30_FinalFilteredInd-GenepopPops.txt \
-d ../stacks_b2_wgenome \
-o batch_2_depthVfis.txt \
-f genepop/batch_2_INFgenepop_parsed_output.txt \
# Out:
# Parsing sample: UP03_048Traceback (most recent call last):
#   File "readDepthVsFis.py", line 95, in <module>
#     tmp_fis = fis_values[pop][locus]
# KeyError: '13357'

# %%
# !python readDepthVsFis_revised.py \
-s genepop/batch_2_FinalFiltered_Ind-GenepopPops.txt \
-d ../stacks_b2_wgenome \
-o batch_2_depthVfis.txt \
-f genepop/batch_2_INFgenepop_parsed_output.txt \
# Out:
# Parsing sample: UP03_048

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/notebooks'

# %%
cd ../analyses
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/analyses

# %% [markdown]
# <br>
# Now I need to plot the average read depth per locus for each population. I can do this by creating two dictionaries for each locus: one for average population read depth, and one for fis value. I'll also create a dictionary of color values, one for each population, in the order that the depth / fis values for each population will be added to the dictionary value lists -- I can't create just a list because there may be populations that do not have a locus present.

# %%
infile = open("batch_2_depthVfis.txt", "r")

## create dictionaries of avg depth and fis per locus per population. ##
## Key = locus. Value = list of population values ##

colors_dict = {}
depth_dict = {}
fis_dict= {}

infile.readline()

for line in infile:
    linelist = line.strip().split()
    locus = linelist[1]
    pop = linelist[0]
    avg_depth = linelist[4]
    fis = linelist[5]
    loci_list = depth_dict.keys()
    if locus not in loci_list:
        depth_dict[locus] = [avg_depth]
        fis_dict[locus] = [fis]
        if "AD" in pop:
            colors_dict[locus] = ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] = ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] = ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] = ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] = ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] = ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] = ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] = ["MediumPurple"]
    elif locus in loci_list:
        depth_dict[locus] += [avg_depth]
        fis_dict[locus] += [fis]
        if "AD" in pop:
            colors_dict[locus] += ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] += ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] += ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] += ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] += ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] += ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] += ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] += ["MediumPurple"]

infile.close()

# %%
print len(depth_dict.keys())
# Out:
# 2410

# %%
print len(fis_dict.keys())
# Out:
# 2410

# %%
print len(colors_dict.keys())
# Out:
# 2410

# %%
fis_list = []
depth_list = []
colors_list = []

for locus in fis_dict.keys():
    for i in fis_dict[locus]:
        fis_list.append(float(i))
    for j in depth_dict[locus]:
        depth_list.append(float(j))
    for k in colors_dict[locus]:
        colors_list.append(k)

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot

plt.scatter(depth_list, fis_list, color = colors_list)

plt.suptitle("Fis v. Avg Read Depth by Locus, by Population")
plt.ylabel("Locus Fis in Population")
plt.xlabel("Locus Avg. Read Depth in Population")

plt.show()

# %%
plt.close()

# %% [markdown]
# #### Looking at only those loci with avg. read depths below 600
#
# The locus with the highest four avg read depths was #6331, and those four populations were the only pops that it was found in.

# %%
infile = open("batch_2_depthVfis_depthLT600.txt", "r")

## create dictionaries of avg depth and fis per locus per population. ##
## Key = locus. Value = list of population values ##

colors_dict = {}
depth_dict = {}
fis_dict= {}

infile.readline()

for line in infile:
    linelist = line.strip().split()
    locus = linelist[1]
    pop = linelist[0]
    avg_depth = linelist[4]
    fis = linelist[5]
    loci_list = depth_dict.keys()
    if locus not in loci_list:
        depth_dict[locus] = [avg_depth]
        fis_dict[locus] = [fis]
        if "AD" in pop:
            colors_dict[locus] = ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] = ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] = ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] = ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] = ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] = ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] = ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] = ["MediumPurple"]
    elif locus in loci_list:
        depth_dict[locus] += [avg_depth]
        fis_dict[locus] += [fis]
        if "AD" in pop:
            colors_dict[locus] += ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] += ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] += ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] += ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] += ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] += ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] += ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] += ["MediumPurple"]

infile.close()

# %%
fis_list = []
depth_list = []
colors_list = []

for locus in fis_dict.keys():
    for i in fis_dict[locus]:
        fis_list.append(float(i))
    for j in depth_dict[locus]:
        depth_list.append(float(j))
    for k in colors_dict[locus]:
        colors_list.append(k)

# %%
#create scatterplot

plt.scatter(depth_list, fis_list, color = colors_list)

plt.suptitle("Fis v. Avg Read Depth by Locus, by Population\n Avg. Read Depths < 600")
plt.ylabel("Locus Fis in Population")
plt.xlabel("Locus Avg. Read Depth in Population")

plt.show()

# %%
plt.close()

# %%
infile = open("batch_2_depthVfis_depthLT600.txt", "r")

## create dictionaries of avg depth and fis per locus per population. ##
## Key = locus. Value = list of population values ##

colors_dict = {}
depth_dict = {}
fis_dict= {}

infile.readline()

for line in infile:
    linelist = line.strip().split()
    locus = linelist[1]
    pop = linelist[0]
    avg_depth = linelist[4]
    fis = linelist[5]
    loci_list = depth_dict.keys()
    if locus not in loci_list and "PWS" not in pop:
        depth_dict[locus] = [avg_depth]
        fis_dict[locus] = [fis]
        if "AD" in pop:
            colors_dict[locus] = ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] = ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] = ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] = ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] = ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] = ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] = ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] = ["MediumPurple"]
    elif locus in loci_list and "PWS" not in pop:
        depth_dict[locus] += [avg_depth]
        fis_dict[locus] += [fis]
        if "AD" in pop:
            colors_dict[locus] += ["Navy"]
        elif "WC" in pop:
            colors_dict[locus] += ["MediumAquamarine"]
        elif "HS" in pop:
            colors_dict[locus] += ["Chartreuse"]
        elif "UP" in pop:
            colors_dict[locus] += ["Gold"]
        elif "GS" in pop:
            colors_dict[locus] += ["DarkSalmon"]
        elif "PS" in pop:
            colors_dict[locus] += ["OrangeRed"]
        elif "PWS" in pop:
            colors_dict[locus] += ["MediumVioletRed"]
        elif "KOD" in pop:
            colors_dict[locus] += ["MediumPurple"]

# %%
fis_list = []
depth_list = []
colors_list = []

for locus in fis_dict.keys():
    for i in fis_dict[locus]:
        fis_list.append(float(i))
    for j in depth_dict[locus]:
        depth_list.append(float(j))
    for k in colors_dict[locus]:
        colors_list.append(k)

# %%
#create scatterplot

plt.scatter(depth_list, fis_list, color = colors_list)

plt.suptitle("Fis v. Avg Read Depth by Locus, by Population\n Avg. Read Depths < 600")
plt.ylabel("Locus Fis in Population")
plt.xlabel("Locus Avg. Read Depth in Population")

plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# <br>
# ### Matching Fis at loci across two populations

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/analyses'

# %%
infile = open("genepop/batch_2_INFgenepop_parsed_output.txt", "r")

kod_dict = {}

up_dict = {}

for line in infile:
    if "locus" not in line:
        if line.startswith("KOD"):
            linelist = line.strip().split()
            kod_dict[linelist[1]] = linelist[4]
        elif line.startswith("UP"):
            linelist = line.strip().split()
            up_dict[linelist[1]] = linelist[4]
infile.close()


loci_listk = kod_dict.keys()
loci_listu = up_dict.keys()

fis_kod = []
fis_up = []

for locus in loci_listk:
    if locus in loci_listu:
        fis_kod.append(kod_dict[locus])
        fis_up.append(up_dict[locus])
print len(fis_kod)
print len(fis_up)
# Out:
# 1914
# 1914

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot

plt.scatter(fis_kod, fis_up)

plt.suptitle("Fis values by Locus, across Two Populations")
plt.ylabel("Kodiak Fis")
plt.xlabel("Unimak Pass Fis")

plt.show()

# %%
print [i for i in fis_kod if float(i) > 0.98]
# Out:
# ['1.0000', '1.0000']

# %% [markdown]
# <br>
# <br>
#
# ### Read depth per allele within a single individual.

# %% [markdown]
# I need to go into the final genepop file and get the list of loci, then for each locus look up the stack depths of each allele.

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/notebooks'

# %%
cd ../analyses
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-US-repo/analyses

# %%
genepop = open("../stacks_b2_wgenome/batch_2_filteredMAF_filteredLoci_filteredIndivids_filteredHWE.txt", "r")

loci_list = []
for line in genepop:
    if not line.startswith("Pop"):
        if "Korea" not in line:
            loci_list.append(line.strip())

genepop.close()

matches = open("../stacks_b2_wgenome/UP03_048.matches.tsv", "r")

matched_loci = []
a1_depth = {}
a2_depth = {}
for line in matches:
    if "sstacks" not in line:
        linelist = line.strip().split()
        locus = linelist[2]
        if locus in loci_list:
            if locus not in matched_loci:
                matched_loci.append(locus)
                a1_depth[locus] = linelist[6]
            elif locus in matched_loci:
                a2_depth[locus] = linelist[6]
matches.close()

# %%
len(a1_depth.keys())
# Out:
# 2384

# %%
len(a2_depth.keys())
# Out:
# 263

# %%
print a2_depth.keys()
# Out:
# ['2965', '4302', '769', '9730', '11198', '2651', '13929', '16179', '8150', '12830', '130', '13657', '12390', '12977', '1546', '16847', '18198', '5989', '6648', '10180', '6574', '5273', '6640', '7611', '11117', '16067', '18299', '1378', '7751', '13487', '9934', '10524', '9274', '4339', '1154', '15938', '3839', '15430', '1490', '5752', '1492', '6445', '16262', '1495', '13414', '10119', '2554', '8338', '12790', '12536', '10966', '4730', '3566', '15059', '10961', '11141', '13310', '1823', '9468', '8703', '14747', '12268', '5857', '5919', '3846', '2257', '18928', '16178', '7895', '17242', '1382', '13732', '12508', '10042', '12901', '1921', '391', '16250', '10237', '12981', '17144', '11208', '4200', '14616', '9494', '8131', '13140', '1712', '6783', '15114', '15641', '6513', '13498', '5096', '2381', '12140', '1018', '17319', '11283', '8966', '3812', '1832', '2769', '9084', '3661', '10131', '6828', '2937', '13865', '7899', '8072', '14049', '9081', '3261', '7909', '9005', '13679', '3249', '5489', '10784', '3311', '7179', '10036', '10221', '6170', '17136', '7867', '1647', '10807', '3462', '2579', '2574', '6507', '14732', '1534', '1416', '11881', '3095', '2679', '4953', '7544', '15825', '6832', '2611', '14650', '11946', '13563', '11346', '16197', '17805', '18290', '8464', '8296', '12967', '12961', '12151', '1633', '6433', '6769', '5704', '18856', '13796', '11428', '7906', '8070', '2367', '5861', '3082', '15730', '7925', '18045', '6808', '10155', '13339', '6423', '11330', '9740', '12979', '5103', '12947', '3172', '17733', '7840', '17520', '15549', '10093', '12353', '17529', '12782', '5342', '6142', '5400', '1922', '1455', '7990', '1100', '8667', '12341', '11351', '14902', '2513', '5114', '10678', '13480', '7285', '1163', '16507', '4247', '4245', '6815', '15705', '12916', '11326', '2948', '16451', '4458', '6622', '8272', '16255', '10577', '11402', '11175', '14552', '1617', '6558', '15302', '16700', '18637', '8766', '326', '1114', '11875', '8840', '4845', '1553', '14398', '16045', '9415', '16996', '8399', '4318', '8395', '4252', '12551', '7947', '3351', '8009', '12044', '1006', '9216', '5738', '17836', '1280', '3543', '4667', '6720', '1683', '2001', '11960', '6331', '17181', '6030', '13417']

# %%
print a2_depth['2965']
# Out:
# 28

# %%
print a2_depth['4302']
# Out:
# 22

# %%
polymorphic_loci = a2_depth.keys()

a1_depthL = []
a2_depthL = []

for locus in polymorphic_loci:
    a1_depthL.append(a1_depth[locus])
    a2_depthL.append(a2_depth[locus])

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
total_depth = {}
for locus in matched_loci:
    if locus in polymorphic_loci:
        new_depth = float(a1_depth[locus]) + float(a2_depth[locus])
        total_depth[locus] = new_depth

# %%
new_depth = float(a1_depth['130']) + float(a2_depth['130'])

# %%
print new_depth
# Out:
# 60.0

# %%
print a1_depth['130']
# Out:
# 26

# %%
print a2_depth['130']
# Out:
# 34

# %%
a1_prop = []
a2_prop = []
for locus in matched_loci:
    if locus in polymorphic_loci:
        a2_prop.append(float(a2_depth[locus])/float(total_depth[locus]))
        a1_prop.append(float(a1_depth[locus])/float(total_depth[locus]))

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(a1_prop, a2_prop)


plt.suptitle("Allele Read Depth in UP03_048")
plt.ylabel("Proportion of Reads Allele 2")
plt.xlabel("Proportion of Reads Allele 1")

plt.show()

# %%
plt.close()

# %%
# plot histogram
plt.hist(a1_prop, bins = np.arange(0,1, 0.01), color = "darkcyan")
plt.xlabel("Proportion of Reads Allele 1")
plt.ylabel("# of Loci")
plt.suptitle("Distribution of Proportion of Reads for Allele 1\n in UP03_48")
plt.show()

# %%
plt.close()

# %% [markdown]
# <br>
# ** SAMPLE TWO:**

# %%
genepop = open("../stacks_b2_wgenome/batch_2_filteredMAF_filteredLoci_filteredIndivids_filteredHWE.txt", "r")

loci_list = []
for line in genepop:
    if not line.startswith("Pop"):
        if "Korea" not in line:
            loci_list.append(line.strip())

genepop.close()

matches = open("../stacks_b2_wgenome/AD06_025.matches.tsv", "r")

matched_loci = []
a1_depth = {}
a2_depth = {}
for line in matches:
    if "sstacks" not in line:
        linelist = line.strip().split()
        locus = linelist[2]
        if locus in loci_list:
            if locus not in matched_loci:
                matched_loci.append(locus)
                a1_depth[locus] = linelist[6]
            elif locus in matched_loci:
                a2_depth[locus] = linelist[6]
matches.close()

# %%
polymorphic_loci = a2_depth.keys()

a1_depthL = []
a2_depthL = []

for locus in polymorphic_loci:
    a1_depthL.append(a1_depth[locus])
    a2_depthL.append(a2_depth[locus])

# %%
total_depth = {}
for locus in matched_loci:
    if locus in polymorphic_loci:
        new_depth = float(a1_depth[locus]) + float(a2_depth[locus])
        total_depth[locus] = new_depth

# %%
a1_prop = []
a2_prop = []
for locus in matched_loci:
    if locus in polymorphic_loci:
        a2_prop.append(float(a2_depth[locus])/float(total_depth[locus]))
        a1_prop.append(float(a1_depth[locus])/float(total_depth[locus]))

# %%
#create scatterplot
plt.scatter(a1_prop, a2_prop)


plt.suptitle("Allele Read Depth in AD06_025")
plt.ylabel("Proportion of Reads Allele 2")
plt.xlabel("Proportion of Reads Allele 1")

plt.show()

# %%
plt.close()

# %%
# plot histogram
plt.hist(a1_prop, bins = np.arange(0,1, 0.01), color = "darkcyan")
plt.xlabel("Proportion of Reads Allele 1")
plt.ylabel("# of Loci")
plt.suptitle("Distribution of Proportion of Reads for Allele 1\n in AD06_025")
plt.show()

# %%
plt.close()

# %% [markdown]
# ** with # of reads instead of proportion **

# %%
a1_num = []
a2_num = []
for locus in matched_loci:
    if locus in polymorphic_loci:
        a2_num.append(float(a2_depth[locus]))
        a1_num.append(float(a1_depth[locus]))

# %%
#create scatterplot
plt.scatter(a1_num, a2_num)


plt.suptitle("Allele Read Depth in AD06_025")
plt.ylabel("# of Reads Allele 2")
plt.xlabel("# of Reads Allele 1")

plt.show()

# %%
plt.close()

# %%
a1_num_adj = [i for i in a1_num if i < 100]

# %%
a2_num_adj = [i for i in a2_num if i < 400]

# %%
len(a1_num_adj)
# Out:
# 281

# %%
len(a2_num_adj)
# Out:
# 281

# %%
#import plotting packages
import matplotlib.pyplot as plt
import numpy as np

# %%
#create scatterplot
plt.scatter(a1_num_adj, a2_num_adj)


plt.suptitle("Allele Read Depth in AD06_025 (low read depths)")
plt.ylabel("# of Reads Allele 2")
plt.xlabel("# of Reads Allele 1")

plt.show()

# %%
plt.close()
