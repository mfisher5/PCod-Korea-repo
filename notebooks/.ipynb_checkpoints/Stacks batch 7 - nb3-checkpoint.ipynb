# %% [markdown]
# ## Stacks batch 7 - notebook 3
#
# This notebook contains:
# 1. pstacks through sstacks
# 2. populations (first time with the write_random_snp option)

# %% [markdown]
# <br>
# <br>
# #### 8/21/2017
# <br>
# ### pstacks --> cstacks --> sstacks

# %%
cd ../scripts
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/scripts

# %%
# !head -n 20 pstacks_sstacks_genShell_8-21.py
# Out:
# ###### Generate Shell Script to Run pstacks --> populations ######
#
# ## MF 3/10/2017
# ## For US Cod Data
#
# ## Edited by MF 5/3/2017 for Korea PCod Data
# ## Edited 6/25/2017 for Korea PCod Data, 8/21/2017 to include batch number as an argument
#
# ## At Command Line: python cstacks_populations_genShell_7-6 ARG1 ARG2
# ##---- ARG1 = complete sample list file, can be population map
# ##---- ARG2 = sample list for building cstacks catalog
# ##---- ARG3 = batch number
#
#
# #############################################################################
#
#
# import sys
#
# sampfilename = sys.argv[1]

# %%
# !python pstacks_sstacks_genShell_8-21.py \
PopMap_L1-5.txt \
samples_for_cstacks_b7.txt \
7

# %%
# !head pstacks_sstacks_b7.sh
# Out:
# #pstacks
# pstacks -t sam -f ../stacks_b7_wgenome/PO010715_02.sam -o ../stacks_b7_wgenome -i 001 -m 10 -p 6 --model_type bounded 2>> ../stacks_b7_wgenome/pstacks_out_b7_wgenome
# pstacks -t sam -f ../stacks_b7_wgenome/PO010715_02_rep.sam -o ../stacks_b7_wgenome -i 002 -m 10 -p 6 --model_type bounded 2>> ../stacks_b7_wgenome/pstacks_out_b7_wgenome
# pstacks -t sam -f ../stacks_b7_wgenome/PO010715_04.sam -o ../stacks_b7_wgenome -i 003 -m 10 -p 6 --model_type bounded 2>> ../stacks_b7_wgenome/pstacks_out_b7_wgenome
# pstacks -t sam -f ../stacks_b7_wgenome/PO010715_06.1.sam -o ../stacks_b7_wgenome -i 004 -m 10 -p 6 --model_type bounded 2>> ../stacks_b7_wgenome/pstacks_out_b7_wgenome
# pstacks -t sam -f ../stacks_b7_wgenome/PO010715_08.1.sam -o ../stacks_b7_wgenome -i 005 -m 10 -p 6 --model_type bounded 2>> ../stacks_b7_wgenome/pstacks_out_b7_wgenome
# ...

# %%
#ran in terminal
./pstacks_sstacks_b7.sh

# %% [markdown]
# <br>
# #### 8/25/2017
# <br>
# ### populations
#
# This run of populations will use the new `write_random_snp` method.

# %%
pwd
# Out:
# u'/mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/notebooks'

# %%
cd ../scripts
# Out:
# /mnt/hgfs/Pacific cod/DataAnalysis/PCod-Korea-repo/scripts

# %%
# !populations -b 7 -P ../stacks_b7_wgenome -M PopMap_L1-5.txt --write_random_snp -t 36 -r 0.80 -p 3 -m 10 --genepop --fasta
# Out:
# Fst kernel smoothing: off
# Bootstrap resampling: off
# Percent samples limit per population: 0.8
# Locus Population limit: 3
# Minimum stack depth: 10
# Log liklihood filtering: off; threshold: 0
# Minor allele frequency cutoff: 0
# Maximum observed heterozygosity cutoff: 1
# Applying Fst correction: none.
# Parsing population map...
# The population map contained 326 samples, 9 population(s), 1 group(s).
# Reading the catalog...
#   Parsing ../stacks_b7_wgenome/batch_7.catalog.tags.tsv
#   Parsing ../stacks_b7_wgenome/batch_7.catalog.snps.tsv
#   Parsing ../stacks_b7_wgenome/batch_7.catalog.alleles.tsv
# Reading matches to the catalog...
#   Parsing ../stacks_b7_wgenome/PO010715_02.matches.tsv
#   Parsing ../stacks_b7_wgenome/PO010715_02_rep.matches.tsv
#   Parsing ../stacks_b7_wgenome/PO010715_04.matches.tsv
#   Parsing ../stacks_b7_wgenome/PO010715_06.1.matches.tsv
#   Parsing ../stacks_b7_wgenome/PO010715_07.matches.tsv
# ...
